# %% [markdown]
# # Pandas pour l'analyse de données

# %% [markdown]
# User guide : https://pandas.pydata.org/docs/user_guide/10min.html
# Cheat Sheet : https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# ## Importer Pandas
#
# Et le format DataFrame

# %%
import pandas as pd

# %% [markdown]
# ## Charger des données
#
# https://zenodo.org/record/5827206/files/SOSP_Export_base%20de%20donn%C3%A9es%20diffusable.csv

# %%
url = "https://zenodo.org/record/5827206/files/SOSP_Export_base%20de%20donn%C3%A9es%20diffusable.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Id                     contexte_travail  \
# 0   1  nous sommes entre 6 et 10 personnes
# 1   2     nous sommes plus de 50 personnes
# 2   3   nous sommes entre 2 et 5 personnes
# 3   4   nous sommes entre 2 et 5 personnes
# 4   5   nous sommes entre 2 et 5 personnes
#
#                                   fonction_recherche  \
# 0  professeur / professeure des universités et as...
# 1                ingénieur / ingénieure de recherche
# 2     maître / maîtresse de conférences et assimilés
# 3  directeur / directrice de recherche (CNRS, INS...
# 4           doctorant / doctorante (y compris CIFRE)
#
#         statut_professionnel statut_professionnel_Autre  annee_premiere_publi  \
# 0  fonctionnaire ou assimilé                        NaN                  1995
# 1                     en CDI                        NaN                  2005
# 2  fonctionnaire ou assimilé                        NaN                  2006
# 3  fonctionnaire ou assimilé                        NaN                  1989
# 4                     en CDD                        NaN                  2015
#
#              Systeme_exploitation Usage_telephone_mobile  \
# 0                         Windows               rarement
# 1                         Windows               rarement
# 2                         Windows                parfois
# 3  Windows;autres OS (Android...)                souvent
# 4                           MacOS                souvent
#
#   Outils_gestion_travail_av_confinement_visioconférence  \
# 0                                            parfois
# 1                                            parfois
# 2                                           rarement
# 3                                           rarement
# 4                                           rarement
#
#   Outils_gestion_travail_av_confinement_planification_RDV  ...  \
# 0                                            souvent       ...
# 1                                            parfois       ...
# 2                                            souvent       ...
# 3                                            souvent       ...
# 4                                            parfois       ...
#
#   Souhait_partage_donnees_produites_discipline  \
# 0                                          oui
# 1                                          oui
# 2                                          oui
# 3                                          oui
# 4                                          oui
#
#   Souhait_partage_donnees_produites_pays_continent  \
# 0                                              oui
# 1                                              oui
# 2                                              oui
# 3                                              oui
# 4                                              oui
#
#   Souhait_partage_donnees_produites_domaine_economique  \
# 0                                                oui
# 1                                                oui
# 2                                                oui
# 3                                                non
# 4                                                oui
#
#   Souhait_partage_donnees_produites_secteur_associatif  \
# 0                                                oui
# 1                                                oui
# 2                                                oui
# 3                                                non
# 4                                                oui
#
#   Souhait_partage_donnees_produites_sans_restriction  \
# 0                                                oui
# 1                                                oui
# 2                                                oui
# 3                                                non
# 4                                                oui
#
#      compatibilite_diffusion_partage evolutions_pratiques_numeriques  \
# 0                                oui                  je ne sais pas
# 1                                NaN                             NaN
# 2  oui, tout est dans la chronologie                             non
# 3                                Oui                     Aucune idée
# 4                                Oui                             Oui
#
#         sexe   disciplines_9niv annee_de_naissance-recod10niv
# 0   un homme  Sciences humaines                   61 à 65 ans
# 1   un homme           Médecine                   46 à 50 ans
# 2   un homme           Médecine                   36 à 40 ans
# 3  une femme           Médecine                   56 à 60 ans
# 4  une femme           Médecine                   31 à 35 ans
#
# [5 rows x 131 columns]

# %%
df.shape
# Out:
# (1089, 131)

# %%
for i in df.columns:
    print(i)
# Out:
# Id
# contexte_travail
# fonction_recherche
# statut_professionnel
# statut_professionnel_Autre
# annee_premiere_publi
# Systeme_exploitation
# Usage_telephone_mobile
# Outils_gestion_travail_av_confinement_visioconférence
# Outils_gestion_travail_av_confinement_planification_RDV
# Outils_gestion_travail_av_confinement_gestion_temps
# Outils_gestion_travail_av_confinement_métier_interne_entreprise
# Outils_gestion_travail_av_confinement_planification_suivi_taches_gestion_projet
# Outils_gestion_travail_av_confinement_services_ligne
# Outils_gestion_travail_av_confinement_redaction_collectif
# Outils_gestion_travail_av_confinement_gestion_references
# Outils_gestion_travail_suite_confinement_visioconference
# Outils_gestion_travail_suite_confinement_planification_RDV
# Outils_gestion_travail_suite_confinement_gestion_temps
# Outils_gestion_travail_suite_confinement_metier_interne_entreprise
# Outils_gestion_travail_suite_confinement_planification_suivi_taches_gestion_projet
# Outils_gestion_travail_suite_confinement_services_ligne
# Outils_gestion_travail_suite_confinement_redaction_collectifs
# Outils_gestion_travail_suite_confinement_gestion_references
# Acces_informations_recherches_instititionnel
# Acces_informations_recherches_moteur_recherche_generalistes
# Acces_informations_recherches_moteur_recherche_scientifiques
# Acces_informations_recherches_pay_per_view
# Acces_informations_recherches_entrepot_donnees
# Acces_informations_recherches_reseaux_numeriques_academiques
# Acces_informations_recherches_archives_ouvertes
# Acces_informations_recherches_bibliotheques_numeriques
# Acces_informations_recherches_demandes_web
# Acces_informations_recherches_extensions_navigateur
# Acces_informations_recherches_bibliotheques_clandestines
# Acces_informations_recherches_demande_auteurs
# decouverte_outils_num_travail
# type_donnees_nombres_valeurs_numeriques
# type_donnees_textes
# type_donnees_images
# type_donnees_videos
# type_donnees_ 3D
# type_donnees_sons
# volumetrie_donnees
# Reutilisation_donnees
# Archive_long_terme
# tiers_archivage
# Tiers_archivage_recod
# crowdsourcing
# outils_sauvegarde_carnets_papier
# Outils_sauvegarde_carnets_numeriques
# Outils_sauvegarde_base_donnees_labo
# Outils_sauvegarde_supports_amovibles
# Outils_sauvegarde_reseau_informatique_local
# Outils_sauvegarde_disque_dur
# Outils_sauvegarde_cloud_institutionnel
# Outils_sauvegarde_cloud_non-institutionnel
# logiciel_production_donnees
# types_logiciels_production_donnees
# Usage_outils_nettoyage
# outils_nettoyage
# Usage_outils_analyse
# Outils_analyses
# Usage_outils_visualisation
# Outils_visualisation
# usage_outils_systemes_qualif_donnees
# Outils_redaction_documents_traitement_texte
# Outils_redaction_documents_traitement_texte_ligne
# Outils_redaction_documents_editeur_Latex
# Outils_redaction_documents_balisage
# Outils_redaction_documents_aide_redaction
# Outils_redaction_documents_formats_specifiques
# Outils_redaction_documents_gestionnaire_references
# Outils_redaction_documents_traduction
# Outils_redaction_documents_PAO
# outils_production_figure
# Formats_presentation_resultats_recherche_communication
# Formats_presentation_resultats_recherche_articles_evaluation_pairs
# Formats_presentation_resultats_recherche_articles_sans_evaluation_pairs
# Formats_presentation_resultats_recherche_chapitre_ouvrage
# Formats_presentation_resultats_recherche_presse
# Formats_presentation_resultats_recherche_document_interne
# Formats_presentation_resultats_recherche_reseaux_sociaux
# Formats_presentation_resultats_recherche_livre
# Formats_presentation_resultats_recherche_billet_web
# Formats_presentation_resultats_recherche_billet_blog_personnel
# Formats_presentation_resultats_recherche_autre
# criteres_soumission_publi
# Pre-print_non_evalues_platerforme_not_for_profit
# Pre-print_non_evalues_reseaux-sociaux-num_academiques
# Pre-print_non_evalues_site_web_personnel
# Diffusion_donnees_produites_complement_plateforme_editeur
# Diffusion_donnees_produites_article_donnees
# Diffusion_donnees_produites_entrepots_generalistes
# Diffusion_donnees_produites_entrepot_disciplinaire
# Diffusion_donnees_produites_résultats_négatifs
# Diffusion_autres_types_production_projet_recherche
# Diffusion_autres_types_production_grant_proposals
# Diffusion_autres_types_production_protocoles
# Diffusion_autres_types_production_notebook
# Diffusion_autres_types_production_codes
# Diffusion_autres_types_production_prorotypes
# Diffusion_autres_types_production_rapports
# Diffusion_autres_types_production_materiels_accompagnement
# Diffusion_autres_types_production_posters
# Diffusion_publications_evaluees_pairs_archives_ouvertes
# Diffusion_publications_evaluees_pairs_entrepots_generalistes
# Diffusion_publications_evaluees_pairs_reseaux_sociaux_num_academiques
# Valorisation_recherche_referencement
# Valorisation_recherche_reseaux_sociaux_num_generalistes
# Valorisation_recherche_reseaux_sociaux_num_academiques
# Valorisation_recherche_presence_num
# Valorisation_recherche_multimédia
# Valorisation_recherche_media_ligne
# Valorisation_recherche_sciences_citoyennes
# Valorisation_recherche_transfert_technologie
# Valorisation_recherche_conferences
# Valorisation_recherche_hackatons
# plateforme_evaluation_ouverte
# quelles_plateforme_ouverte
# Souhait_partage_donnees_produites-partenariat
# Souhait_partage_donnees_produites_discipline
# Souhait_partage_donnees_produites_pays_continent
# Souhait_partage_donnees_produites_domaine_economique
# Souhait_partage_donnees_produites_secteur_associatif
# Souhait_partage_donnees_produites_sans_restriction
# compatibilite_diffusion_partage
# evolutions_pratiques_numeriques
# sexe
# disciplines_9niv
# annee_de_naissance-recod10niv

# %% [markdown]
# ## Explorer les données

# %% [markdown]
# **Quelques outils utiles :**
# - `.info()` des infos sur notre df
# - `.shape` sa "forme"
# - `.columns` les colonnes
# - `.dtypes` le type des données
# - `.head()` afficher les premières observations
# - `.tail()` afficher la fin du df
# - `.describe()` description basique

# %% [markdown]
# ## Manipuler un DataFrame
#
# - sélectionner une colonne, une ligne, un élément
# - comprendre l'indexation (iloc, loc)

# %% [markdown]
# ## Calculer sur des colonnes

# %% [markdown]
# Quelques outils utiles pour décrire les données :
#
# - `mean()`
# - `std()`
# - `min()`
# - `max()`
# - `count()`
# - `describe()`
# - `unique()` (et `nunique()`)
# - `value_counts()`

# %% [markdown]
# ## Aller vers une base de données
#
# - filtrer
# - grouper
# - aller plus loin (join, etc.)

# %% [markdown]
# ## Modifier le tableau
#
# - colonnes, index
# - contenu

# %% [markdown]
# ## Recoder
#
# - remplacer
# - valeurs nulles
# - fonctions comme .cut
# - solition générique de .apply

# %% [markdown]
# ## Faire des statistiques
#
# - univariées
# - bivariées : tableau croisé
# - grouper des tableaux (.concat)
# - visualisations

# %% [markdown]
# ## Sauvegarder les données

# %% [markdown]
# ## Et plein d'autres choses
#
# - échantillon aléatoire avec .sample()
